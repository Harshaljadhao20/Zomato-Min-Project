# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshaljadhao20/Zomato-Min-Project/blob/main/Zomato_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Zomato data .csv")

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %% [markdown]
# Convert the data type of column - rate

# %%
def handleRate(value) :
  value = str(value).split("/")
  value = value[0]
  return float(value)

df["rate"] = df["rate"].apply(handleRate)
print(df.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# Q1) What type of restsurant do the majoruty of customers order from ?

# %%
df.head(5)
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=df["listed_in(type)"])
plt.xlabel("Type of restsurant")
# Out:
# Text(0.5, 0, 'Type of restsurant')

# %% [markdown]
# Conclusion :- majority of the resturant falls in dinning category

# %% [markdown]
# Q2) How many votes has each type of restaurant received from customers ?

# %%
df.head(5)
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
grouped_df = df.groupby("listed_in(type)")["votes"].sum()
result = pd.DataFrame({"votes" : grouped_df})
plt.plot(result, c= "red", marker = "o")
plt.xlabel("Type of restaurant ", c="b", size=20)
plt.ylabel("votes", c="green", size=20)
# Out:
# Text(0, 0.5, 'votes')

# %% [markdown]
# Conclusion :- dinning resturants has recieved maximum vates

# %% [markdown]
# Q3) What are the ratings that manjority of restaurants  have received ?

# %%
plt.hist(df["rate"], bins=5)
plt.title("Resturants Recived")
plt.show()

# %% [markdown]
# Conclusion :- The manjority resturants recived ratings is 3.5 to 4

# %% [markdown]
# Q4) Zomate has observed that most comples order most of their food online. What is their average spanding on each order ?

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
couple_data = df["approx_cost(for two people)"]

sns.countplot(x = couple_data  , palette="Paired" )
# Out:
# /tmp/ipython-input-4099706484.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = couple_data  , palette="Paired" )
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# Conclusion :- The manjority of cuples preferr resturants with an approximant cost 300 rupees

# %% [markdown]
# Q5) Which mode (online or offline) has received the maximum rating ?

# %%
plt.figure(figsize= (6,6))
sns.boxplot(x= "online_order" , y = "rate", data= df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# Conlusion :- offline order received lower rating comparison to online order

# %% [markdown]
#  Q6) Which type of restaurant recived more offline orders, os that Zomato cam=n provide customers with some good offers ?

# %%
pivot_table = df.pivot_table(index="listed_in(type)", columns="online_order", aggfunc="size", fill_value=0)

sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt="d")
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (type)")
plt.show()

# %% [markdown]
# Conclusioin :- Dining restarants primarily accept offline orders, whereas cafes primarily receive online orders. This suggests that clints preferns orders in person at restaurantsn, but prefe online ordering at cafes.
